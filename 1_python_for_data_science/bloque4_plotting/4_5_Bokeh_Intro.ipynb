# %% [markdown]
# # Gráficos para la Web con Bokeh

# %% [markdown]
# La biblioteca Bokeh (http://bokeh.pydata.org/) permite crear visualizaciones en Python, pero orientadas a su utilización en navegadores Web. El objetivo es conseguir:
# * visualizaciones interactivas al estilo de D3.js pero permitiendo su programación en Python
# * y dando soporte a streams de datos.
#
# Dado que un Notebook de Jupyter utiliza HTML para visualizar los resultados, Bokeh se integra con los Notebooks, como puede verse en los [ejemplos de bokeh](http://nbviewer.ipython.org/github/bokeh/bokeh-notebooks/blob/master/index.ipynb).
#
# Bokeh se inspira en la notación [Grammar of Graphics de Wilkinson](https://www.cs.uic.edu/~wilkinson/TheGrammarOfGraphics/GOG.html), al igual que el paquete [ggplot2](http://ggplot2.org/) de R, pero no son compatibles.

# %% [markdown]
# Para instalarlo, se puede utilizar pip o conda. Si tenemos Anaconda lo mejor es:
# ```
# conda install bokeh
# ```

# %% [markdown]
# Es fundamental entender que Bokeh es una interfaz que utiliza JavaScript en el navegador para la visualización, por lo que la programación se puede hacer en otros lenguajes que no son Python, por ejemplo en [R](https://hafen.github.io/rbokeh/#background).
# ![Bokeh](http://i1.wp.com/www.analyticsvidhya.com/wp-content/uploads/2015/08/Bokeh_Intro.png?zoom=2&resize=398%2C339)

# %% [markdown]
# ## Los tres niveles en Bokeh

# %% [markdown]
# Bokeh se puede utilizar en tres niveles:
# * low-level *bokeh.models* interface, máxima flexibilidad, pero hay que hacerlo todo parte a parte.
# * intermediate-level *bokeh.plotting* interface, centrado en la composición de glifos visuales (glyphs).
# * high-level *bokeh.charts* interface que simplifican la tarea de hacer visualizaciones o gráficos complejos, tomándolos de un catálogo pre-construido.

# %% [markdown]
# ## Bokeh como paleta de componentes

# %% [markdown]
# Bokeh puede utilizad como salidas diferentes formatos, entre ellos el del propio Notebook.

# %%
from bokeh.io import output_notebook, show
output_notebook() # Configura el Notebook como salida por defecto.
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="fc1b57af-bd96-4258-83d6-feb903fbbc6b">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# Si utilizamos la interfaz **charts** solo tenemos que importar el tipo de gráfico que queramos.

# %% [markdown]
# Por ejemplo, vamos a cargar el dataset de películas de IMDB que está en el paquete ggplot2 de R (pueden consultarse [aquí](http://vincentarelbundock.github.io/Rdatasets/)).

# %%
#import statsmodels.api as sm
#imdb = sm.datasets.get_rdataset("movies", "ggplot2")
#print imdb.__doc__
import pandas as pd

data = pd.read_csv("movie_metadata.csv")
data.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy
# 2                 11000.0  200074175.0        Action|Adventure|Thriller
# 3                 27000.0  448130642.0                  Action|Thriller
# 4                   131.0          NaN                      Documentary
#
#           ...          num_user_for_reviews language  country  content_rating  \
# 0         ...                        3054.0  English      USA           PG-13
# 1         ...                        1238.0  English      USA           PG-13
# 2         ...                         994.0  English       UK           PG-13
# 3         ...                        2701.0  English      USA           PG-13
# 4         ...                           NaN      NaN      NaN             NaN
#
#         budget  title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0  237000000.0      2009.0                  936.0        7.9          1.78
# 1  300000000.0      2007.0                 5000.0        7.1          2.35
# 2  245000000.0      2015.0                  393.0        6.8          2.35
# 3  250000000.0      2012.0                23000.0        8.5          2.35
# 4          NaN         NaN                   12.0        7.1           NaN
#
#   movie_facebook_likes
# 0                33000
# 1                    0
# 2                85000
# 3               164000
# 4                    0
#
# [5 rows x 28 columns]

# %%
from bokeh.charts import Scatter
samplesize = 200 # With the full dataset it becomes slow.
tools = "pan, box_zoom, reset, resize" # omit the annoying "wheel_zoom"

p = Scatter(data[:samplesize], x="duration", y="imdb_score", 
            color="color", tools=tools, legend="top_right")
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="8f91f8bd-e41a-4912-930b-214e701671c4"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#8f91f8bd-e41a-4912-930b-214e701671c4").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8f91f8bd-e41a-4912-930b-214e701671c4");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8f91f8bd-e41a-4912-930b-214e701671c4' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"03a77392-f877-49b1-93e5-8e782a8da93a":{"roots":{"references":[{"attributes":{"callback":null,"end":230.5,"start":44.5},"id":"83614f03-3c39-4d53-94a6-55bdab69430e","type":"Range1d"},{"attributes":{"data_source":{"id":"cf478ecd-cf38-44f0-8816-22850d3452c3","type":"ColumnDataSource"},"glyph":{"id":"d3df098e-acaf-43b3-a115-3f4f71ee6ec5","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"04c6db5e-c837-47e2-9535-02f84b6a75b2","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"c4a78835-f6ef-43a9-a222-64a762b4f883","subtype":"Chart","type":"Plot"}},"id":"37295b2e-48ae-4d57-ae23-4a58132b67d3","type":"ResetTool"},{"attributes":{"dimension":1,"plot":{"id":"c4a78835-f6ef-43a9-a222-64a762b4f883","subtype":"Chart","type":"Plot"},"ticker":{"id":"eea2dc55-9cbd-44ed-baed-b837195d55c6","type":"BasicTicker"}},"id":"17b68905-4d1b-4d7c-a4f9-786d77840007","type":"Grid"},{"attributes":{"plot":{"id":"c4a78835-f6ef-43a9-a222-64a762b4f883","subtype":"Chart","type":"Plot"}},"id":"3cb114a3-44aa-4dec-a05d-013901241f57","type":"PanTool"},{"attributes":{"axis_label":"imdb_score","formatter":{"id":"f7868c35-07a5-4b4e-b4fd-06211eb9df1b","type":"BasicTickFormatter"},"plot":{"id":"c4a78835-f6ef-43a9-a222-64a762b4f883","subtype":"Chart","type":"Plot"},"ticker":{"id":"eea2dc55-9cbd-44ed-baed-b837195d55c6","type":"BasicTicker"}},"id":"87f5186a-6eba-4357-870c-df3053f501ba","type":"LinearAxis"},{"attributes":{"callback":null,"end":9.48,"start":3.72},"id":"ba02abd6-f4f1-4a35-b954-b228a8ced909","type":"Range1d"},{"attributes":{"below":[{"id":"b6a10e16-d8c1-4dbc-8925-d3ef6e0c566f","type":"LinearAxis"}],"left":[{"id":"87f5186a-6eba-4357-870c-df3053f501ba","type":"LinearAxis"}],"renderers":[{"id":"f7b45453-8fb8-427d-b0e2-78cd48266d56","type":"BoxAnnotation"},{"id":"117367f1-609a-4575-8e85-3f737627120b","type":"GlyphRenderer"},{"id":"04c6db5e-c837-47e2-9535-02f84b6a75b2","type":"GlyphRenderer"},{"id":"1dd9108c-c519-42a7-8555-32122d789bc2","type":"Legend"},{"id":"b6a10e16-d8c1-4dbc-8925-d3ef6e0c566f","type":"LinearAxis"},{"id":"87f5186a-6eba-4357-870c-df3053f501ba","type":"LinearAxis"},{"id":"966fa359-2da6-4440-b773-be17e89bf57b","type":"Grid"},{"id":"17b68905-4d1b-4d7c-a4f9-786d77840007","type":"Grid"}],"title":{"id":"5faad813-3e66-4614-9258-08b9b5a28e89","type":"Title"},"tool_events":{"id":"776a88d1-a813-444f-beea-ba8e53cd9305","type":"ToolEvents"},"toolbar":{"id":"591bbed6-5d32-4d9e-a22a-74ae0d66f035","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"83614f03-3c39-4d53-94a6-55bdab69430e","type":"Range1d"},"y_mapper_type":"auto","y_range":{"id":"ba02abd6-f4f1-4a35-b954-b228a8ced909","type":"Range1d"}},"id":"c4a78835-f6ef-43a9-a222-64a762b4f883","subtype":"Chart","type":"Plot"},{"attributes":{"plot":{"id":"c4a78835-f6ef-43a9-a222-64a762b4f883","subtype":"Chart","type":"Plot"},"ticker":{"id":"e8f3cb93-6878-456b-ad5d-73b897a130e4","type":"BasicTicker"}},"id":"966fa359-2da6-4440-b773-be17e89bf57b","type":"Grid"},{"attributes":{"plot":{"id":"c4a78835-f6ef-43a9-a222-64a762b4f883","subtype":"Chart","type":"Plot"}},"id":"973c8e1e-5144-4c0b-b608-eb5eaf0408ef","type":"ResizeTool"},{"attributes":{"axis_label":"duration","formatter":{"id":"23d0c048-0aa4-4a36-b78e-0a6c5de5c5e8","type":"BasicTickFormatter"},"plot":{"id":"c4a78835-f6ef-43a9-a222-64a762b4f883","subtype":"Chart","type":"Plot"},"ticker":{"id":"e8f3cb93-6878-456b-ad5d-73b897a130e4","type":"BasicTicker"}},"id":"b6a10e16-d8c1-4dbc-8925-d3ef6e0c566f","type":"LinearAxis"},{"attributes":{},"id":"eea2dc55-9cbd-44ed-baed-b837195d55c6","type":"BasicTicker"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"d3df098e-acaf-43b3-a115-3f4f71ee6ec5","type":"Circle"},{"attributes":{},"id":"776a88d1-a813-444f-beea-ba8e53cd9305","type":"ToolEvents"},{"attributes":{},"id":"23d0c048-0aa4-4a36-b78e-0a6c5de5c5e8","t ...

# %% [markdown]
# Podemos ahora observar las valoraciones de acuerdo a la clasificación [MPAA](https://en.wikipedia.org/wiki/Motion_Picture_Association_of_America_film_rating_system). Pero podemos observar que hay muchos valores nulos, que tenemos que excluir del análisis.

# %%
import numpy as np
print np.unique(data["content_rating"])
print data.groupby("content_rating")["movie_title"].count()
# Out:
# [nan 'Approved' 'G' 'GP' 'M' 'NC-17' 'Not Rated' 'PG' 'PG-13' 'Passed' 'R'
#  'TV-14' 'TV-G' 'TV-MA' 'TV-PG' 'TV-Y' 'TV-Y7' 'Unrated' 'X']
# content_rating
# Approved       55
# G             112
# GP              6
# M               5
# NC-17           7
# Not Rated     116
# PG            701
# PG-13        1461
# Passed          9
# R            2118
# TV-14          30
# TV-G           10
# TV-MA          20
# TV-PG          13
# TV-Y            1
# TV-Y7           1
# Unrated        62
# X              13
# Name: movie_title, dtype: int64

# %%
from bokeh.charts import BoxPlot
b = BoxPlot(data.dropna(how="any", subset=["content_rating", "imdb_score"]), 
            values="imdb_score", label="content_rating", tools=tools)
show(b)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="1158b9dc-b593-4612-900b-dfd65fbee8df"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#1158b9dc-b593-4612-900b-dfd65fbee8df").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1158b9dc-b593-4612-900b-dfd65fbee8df");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1158b9dc-b593-4612-900b-dfd65fbee8df' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"8ff4740b-a14e-4c22-bdcb-e2900d4b3f49":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"3f064742-e46b-4f14-a1c6-0b4e7a77f4d3","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"209a5239-a712-43e7-ae61-e080f6190ea7","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c762cc70-7630-434b-8007-34a914c6fe27","type":"Rect"},{"attributes":{"data_source":{"id":"949952f9-e176-47b6-9a57-d9c267b5ff24","type":"ColumnDataSource"},"glyph":{"id":"c762cc70-7630-434b-8007-34a914c6fe27","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"7d638e1d-d633-4d9c-bd74-85ea72736533","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"content_rating":"TV-PG"},{"content_rating":"TV-PG"},{"content_rating":"TV-PG"}],"content_rating":["TV-PG","TV-PG","TV-PG"],"x_values":["TV-PG:0.5","TV-PG:0.5","TV-PG:0.5"],"y_values":[5.5,5.8,6.3]}},"id":"df72d2c6-f881-48ea-9c3a-14c4a81e476e","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":[{"content_rating":"Not Rated"}],"color":["DimGrey"],"content_rating":["Not Rated"],"fill_alpha":[0.8],"height":[0.9000000000000004],"label":[{"content_rating":"Not Rated"}],"line_alpha":[1.0],"line_color":["black"],"width":[0.8],"x":["Not Rated"],"y":[7.25]}},"id":"d7395147-74e0-4dc9-bb3a-a91188669191","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"3e7a8440-b4c2-4ab5-bc6f-741f9ea32d61","type":"ColumnDataSource"},"glyph":{"id":"44e8e932-e076-483b-aed0-10ce87a4b253","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"9dbd3879-0dd2-4988-a8a5-4045a740d7f6","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":[{"content_rating":"TV-PG"}],"color":["DimGrey"],"content_rating":["TV-PG"],"fill_alpha":[0.8],"height":[0.20000000000000018],"label":[{"content_rating":"TV-PG"}],"line_alpha":[1.0],"line_color":["black"],"width":[0.8],"x":["TV-PG"],"y":[7.4]}},"id":"e33d669a-8c74-41d8-b325-0e99d6a51476","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"b609090c-7f96-406b-af01-17c4eb9424d2","type":"ColumnDataSource"},"glyph":{"id":"32039126-edff-46fd-9c18-9a9d1d2d2b00","type":"Segment"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"3680258b-f7cc-446f-9d15-71397721d267","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"4e083e1f-36eb-4aa6-9fd1-76feea61368f","type":"ColumnDataSource"},"glyph":{"id":"2e83aef8-d666-4f85-b5ed-189e7aec9619","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"fa00b72c-8701-45a4-b272-4a15ae2ca8a7","type":"GlyphRenderer"},{"attributes":{"callback":null,"end":9.845},"id":"5d7ee23f-7718-4f84-828e-84d7e450395a","type":"Range1d"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":[{"content_rating":"G"}],"color":["DimGrey"],"content_rating":["G"],"fill_alpha":[0.8],"height":[0.9000000000000004],"label":[{"content_rating":"G"}],"line_alpha":[1.0],"line_color":["black"],"width":[0.8],"x":["G"],"y ...

# %%
b = BoxPlot(data.dropna(how="any", subset=["content_rating", "budget"]), \
            values="budget", label="content_rating", tools=tools)
show(b)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="4a2d1694-6c71-4019-a6d3-75a420380cbc"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#4a2d1694-6c71-4019-a6d3-75a420380cbc").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4a2d1694-6c71-4019-a6d3-75a420380cbc");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4a2d1694-6c71-4019-a6d3-75a420380cbc' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"cc27b384-0ff8-4f6d-a102-743c22522294":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"919b4b41-c683-442b-afa4-baa8ffbabdf9","type":"Rect"},{"attributes":{"line_width":{"value":2},"x0":{"field":"x0s"},"x1":{"field":"x1s"},"y0":{"field":"y0s"},"y1":{"field":"y1s"}},"id":"43235a68-92f7-46a3-bc19-85c7f9a964fe","type":"Segment"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":[{"content_rating":"Approved"}],"color":["DimGrey"],"content_rating":["Approved"],"fill_alpha":[0.8],"height":[1050000.0],"label":[{"content_rating":"Approved"}],"line_alpha":[1.0],"line_color":["black"],"width":[0.8],"x":["Approved"],"y":[3475000.0]}},"id":"f3b116d7-a866-4ced-aa49-cc774fbfb4ba","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":[{"content_rating":"TV-G"}],"color":["DimGrey"],"content_rating":["TV-G"],"fill_alpha":[0.8],"height":[200000.0],"label":[{"content_rating":"TV-G"}],"line_alpha":[1.0],"line_color":["black"],"width":[0.8],"x":["TV-G"],"y":[4100000.0]}},"id":"cadf9fc9-3435-4b00-b661-5113369c90dc","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x0s","y0s","x1s","y1s"],"data":{"chart_index":[{"content_rating":"Approved"},{"content_rating":"Approved"},{"content_rating":"Approved"},{"content_rating":"Approved"}],"content_rating":["Approved","Approved","Approved","Approved"],"x0s":["Approved:0.5","Approved:0.65","Approved:0.5","Approved:0.65"],"x1s":["Approved:0.5","Approved:0.35","Approved:0.5","Approved:0.35"],"y0s":[62000.0,62000.0,4000000.0,7833199.0],"y1s":[1444534.0,62000.0,7833199.0,7833199.0]}},"id":"d567d71e-a384-40f2-8143-678f88b9ba99","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":[{"content_rating":"GP"}],"color":["DimGrey"],"content_rating":["GP"],"fill_alpha":[0.8],"height":[3800000.0],"label":[{"content_rating":"GP"}],"line_alpha":[1.0],"line_color":["black"],"width":[0.8],"x":["GP"],"y":[6500000.0]}},"id":"3fbb667f-ed0b-455c-b025-095159fddef3","type":"ColumnDataSource"},{"attributes":{"line_width":{"value":2},"x0":{"field":"x0s"},"x1":{"field":"x1s"},"y0":{"field":"y0s"},"y1":{"field":"y1s"}},"id":"d8c48bb1-1632-4661-b03b-8911cf114524","type":"Segment"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":[{"content_rating":"M"}],"color":["DimGrey"],"content_rating":["M"],"fill_alpha":[0.8],"height":[1550000.0],"label":[{"content_rating":"M"}],"line_alpha":[1.0],"line_color":["black"],"width":[0.8],"x":["M"],"y":[4225000.0]}},"id":"4c92954f-cd57-45eb-9c8c-3a40e163c3cc","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"4ab38a7f-bc16-4181-862e-ac8bef4b60d8","type":"ColumnDataSource"},"glyph":{"id":"37dac184-06c3-4b76-b3a3-41427aea614b","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"2bceb5a9-ef6a-4c67-99e6-c66da63bf1f3","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"red"},"line_color":{"value":"red"},"size":{"units":"screen","value":5},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"bf78bcb7-7b00-4ad8-8020-8cb470628d2a","type":"Circle"},{"attributes":{"plot":{"id":"b19a2fe7-0050-4b8e-8c2c-6a106cbcab72","subtype":"Chart","type":"Plot"}},"id":"3b314c08-1087-4601-a52a-f65a694261bd","type":"ResetTool"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","widt ...

# %% [markdown]
# Si hacemos el boxplot sobre el número de votos, ¿qué nos indica el gráfico resultante sobre la distribución de votos en IMDB?

# %%
from bokeh.charts import Bar
# stack is a grouping feature
br = Bar(data[data["title_year"]>1990].dropna(how="any", subset=["content_rating"]), 
         label="title_year", 
         values="title_year", stack="content_rating", agg="count", tools=tools, legend="top_right" )
show(br)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="7db0ea50-ca1d-4540-b5c0-90d2a05c457e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#7db0ea50-ca1d-4540-b5c0-90d2a05c457e").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7db0ea50-ca1d-4540-b5c0-90d2a05c457e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7db0ea50-ca1d-4540-b5c0-90d2a05c457e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"7d622c1e-051f-45d4-89e0-fcf8c628c485":{"roots":{"references":[{"attributes":{"data_source":{"id":"95f8237a-fe16-4885-8ce5-d2e2071992ee","type":"ColumnDataSource"},"glyph":{"id":"4cdaa0f6-b14a-433a-afce-475ebe78da4b","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"876caf6e-e128-4a30-ac55-37b0c929c2b3","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":[{"content_rating":"R","title_year":1993.0}],"color":["#c33ff3"],"content_rating":["R"],"fill_alpha":[0.8],"height":[22.0],"label":[{"content_rating":"R","title_year":1993.0}],"line_alpha":[1.0],"line_color":["white"],"title_year":[1993.0],"width":[0.8],"x":["1993.0"],"y":[23.0]}},"id":"6b2f5c1c-ac7a-4ffa-b027-604ffb3ba623","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"68fd8112-4764-4b9e-a33d-8adc10e9295d","type":"Rect"},{"attributes":{"data_source":{"id":"546eb5e2-6c18-424b-925b-767bcc313618","type":"ColumnDataSource"},"glyph":{"id":"45851c0d-1787-46e5-b84b-ff91cb2cb29d","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"1c9c86cd-f832-4ab6-b19d-4bdeb51c0dd9","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"64d6061c-8218-4819-b637-ee438c70550e","type":"ColumnDataSource"},"glyph":{"id":"bfd28994-0f47-418a-b1e6-c3ea6cea6c86","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"89124ec0-8caa-4663-bfc6-52c49f9e5e77","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"3d20511c-0f38-4c6f-bb27-48d389a3a073","type":"Rect"},{"attributes":{"data_source":{"id":"c2da1ca4-1ac5-4d7b-9982-571737a6f4d9","type":"ColumnDataSource"},"glyph":{"id":"ae9b085d-c934-4131-81a7-37d0bb4797d2","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"621b69fd-69ae-454b-97c0-8b04e6d9d0a6","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":[{"content_rating":"TV-G","title_year":2007.0}],"color":["#5ab738"],"content_rating":["TV-G"],"fill_alpha":[0.8],"height":[1.0],"label":[{"content_rating":"TV-G","title_year":2007.0}],"line_alpha":[1.0],"line_color":["white"],"title_year":[2007.0],"width":[0.8],"x":["2007.0"],"y":[185.5]}},"id":"3971c205-2e01-4af3-ae9c-f05eeb48b0dd","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"20fc0153-0c42-4b3e-aeff-3291e1e203c2","type":"Rect"},{"attributes":{"data_source":{"id":"589844a2-a29f-42bf-ac4c-7041891e345d","type":"ColumnDataSource"},"glyph":{"id":"7460b32a-637c-49bd-826a-4b3cc6305cb3","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"4bf49d58-94b5-45d7-b879-e881f7169293","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"31015c1d-3b77-40ec-9465-9f391f03bffa","type":"Rect"},{"attributes":{"data_source":{"id":"792d55b2-abea-4137-a6ad-ddf78152925b","type":"ColumnDataSource"},"glyph":{"id":"09ce1245-1439-4115-9967-2d1e92330420","type":"Rect"},"h ...

# %% [markdown]
# ## Bokeh y Big Data

# %% [markdown]
# En lo visto hasta aquí, los datos están en memoria (DataFrame de pandas) y Bokeh los utiliza íntegramente, lo cual deja de ser práctico cuando hay muchos datos a mostrar en un solo gráfico.

# %% [markdown]
# Bokeh integra la posibilidad de utilizar [WebGL](http://bokeh.pydata.org/en/latest/docs/user_guide/webgl.html#userguide-webgl) para acelerar mediante la Graphics Processing Unit (GPU) el javascript generado. Esto simplemente aprovecha una característica presente en la mayoría de los navegadores modernos.

# %% [markdown]
# Otra posibilidad es utilizar un Servidor de Bokeh, de modo que los gráficos se actualizan en el servidor y los clientes JavaScript proporcionan una vista.
#
# ![Bokeh Server](http://bokeh.pydata.org/en/0.8.2/_images/bokeh_server.png)

# %% [markdown]
# Por último, Bokeh se puede combinar con proyectos como [Blaze](http://blaze.readthedocs.org/en/latest/index.html), una biblioteca que trata de proporcionar una interfaz de programación parecida a los DataFrames de pandas, pero actuando sobre conjuntos de datos grandes, que en ocasiones no se pueden tener en memoria.
#
# https://www.youtube.com/watch?v=mC2uEUyeNWQ
